# %% [markdown]
# ## Part 1: Distance statistics between nightlife businesses within each neighborhood

# %%
import pandas as pd
import geopandas as gpd
import numpy as np 
from scipy import stats
from sklearn.neighbors import NearestNeighbors

# %%
nightlife = pd.read_csv('XYZ_wOutliers.csv')

# %%
#Get all rows that have longlats within the zip code boundaries
#1.8% of all data has points outside the zip code boundaries which will not be counted in this calculation

nightlife_within = nightlife[nightlife['outsideZip'] == 0]

# %%
#Create list of all neighborhoods
hoods = nightlife_within['Neighborho'].unique()

# %%
#function to calculate distance
def distance(p1, p2):
    """
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)
    """
    lon1, lat1 = p1
    lon2, lat2 = p2
    # convert decimal degrees to radians
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])
    # haversine formula
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    km = 6367 * c
    ft = km * 3280.84
    return ft

# %%
#create new dataframe
columns = ['mean (ft)','min (ft)','max (ft)','variance','skewness']
finalStats = pd.DataFrame(index=hoods, columns=columns)

# %%
#calculate distance statistics in feet
for x in hoods:
    workingHood = nightlife_within[nightlife_within['Neighborho'] == x].copy()
    
    points = [(x, y) for x,y in zip(workingHood['latitude'], workingHood['longitude'])]
    nbrs = NearestNeighbors(n_neighbors=2, metric=distance).fit(points)
    distances, indices = nbrs.kneighbors(points)
    result = distances[:, 1]
    
    finalStats.loc[x, 'mean (ft)'] = result.mean()
    finalStats.loc[x, 'min (ft)'] = result.min()
    finalStats.loc[x, 'max (ft)'] = result.max()
    finalStats.loc[x, 'variance'] = result.var()
    finalStats.loc[x, 'skewness'] = stats.skew(result)
    
finalStats
# Out:
#                                mean (ft) min (ft) max (ft)     variance  \
# Elmhurst                         111.577  4.22628  884.339      22286.4
# Chelsea                          61.1815  2.35878  49370.2  1.04949e+06
# South Bronx                      96.4843  5.21117  465.701      7927.57
# Williamsburg                     67.1671  1.62975  540.753      3944.66
# Astoria/LIC                      91.4487  3.75649  10790.5       144471
# Bed-Stuy                         63.5672  1.46827  614.529      6687.12
# Ridgewood                        117.782  5.67773  1102.88      19269.2
# LES                              34.9395   3.2355  471.175      1304.53
# Inwood                           63.2641  5.74869  1354.21      12375.7
# Flushing                         74.9585  2.78351  1450.77      17931.5
# Harlem                           72.4802   5.2185   466.21      4737.55
# Bushwick                         162.679  10.0542  5982.64       207540
# Greenpoint                       78.6035  5.52674  391.681      6415.11
# Jackson Heights                  58.8193  4.53485  427.991      3464.66
# Williamsburg/Bushwick/Bed-Stuy   116.131  2.33767  4321.13       113818
# Bed-Stuy/Bushwick                110.678  5.73314  2878.75      51152.9
# LIC                              71.4014  10.8726  953.552      13015.2
#
#                                skewness
# Elmhurst                        2.55031
# Chelsea                         46.0548
# South Bronx                     1.78995
# Williamsburg                    2.68974
# Astoria/LIC                     25.4733
# Bed-Stuy                        3.11284
# Ridgewood                       3.94466
# LES                             5.17127
# Inwood                          8.67937
# Flushing                         4.9472
# Harlem                          2.36019
# Bushwick                         11.425
# Greenpoint                      1.65674
# Jackson Heights                  3.4444
# Williamsburg/Bushwick/Bed-Stuy  10.0826
# Bed-Stuy/Bushwick               10.4159
# LIC                              6.1747

# %%
finalStats.to_csv('neighborhoodsDistanceStats.csv')

# %% [markdown]
# ## Part 2: Category variety within each neighborhood (XYZ vs. Yelp)

# %%
#new pivot for neighborhoods and their business categories
xyzCat = pd.crosstab(nightlife.Neighborho, nightlife.primary_ca)

# %% [markdown]
# Calculate percent of category of all categories per neighborhood

# %%
#new column for total num businesses/neighborhood
xyzCat['Total'] = xyzCat.sum(axis=1)

# %%
for x in range(len(xyzCat)):
    for y in range(14):
        xyzCat.iloc[x,y] = (xyzCat.iloc[x,y]/xyzCat.iloc[x,14]*100).round(2)

# %% [markdown]
# Calculate percent of category of all categories in all neighborhoods

# %%
#new table for categories
xyzCat_counts = nightlife.groupby(['primary_ca']).size().reset_index(name='counts')

# %%
#count of businesses
total = xyzCat_counts['counts'].sum()

# %%
#calculate percent of total (percent distribution)
xyzCat_counts['nycPercentDist'] = (xyzCat_counts['counts']/total*100).round(2)
xyzCat_counts
# Out:
#         primary_ca  counts  nycPercentDist
# 0   Arts & Culture     471            5.51
# 1             Body       4            0.05
# 2           Drinks    1212           14.18
# 3    Entertainment     291            3.40
# 4       Essentials     562            6.57
# 5          Fashion       9            0.11
# 6          Fitness       3            0.04
# 7             Food    5448           63.73
# 8           Groups     220            2.57
# 9     Home & Hobby      16            0.19
# 10         Lodging     299            3.50
# 11            Misc       9            0.11
# 12     Parks & Rec       2            0.02
# 13        Services       2            0.02

# %% [markdown]
# Use the new column <b>xyzCat_counts['nycPercentDist']</b> as threshold for being counted into variety within a neighborhood

# %%
#new dataframe xyzCat, add new column for num of existing categories per neighborhood and for variety count

xyzCat_new = xyzCat.drop(['Total'],axis=1)
xyzCat_new['NumCategories'] = 0
xyzCat_new['VarietyCount'] = 0

# %%
#pos = count num of existing categories per neighborhood
#tally = count number of existing categories that have a percentage equal to or greater than the city distribution

for x in range(len(xyzCat_new)):
    pos = 0
    tally = 0
    for y in range(14):
        if xyzCat_new.iloc[x,y] > 0:
            pos += 1
        if ((xyzCat_new.iloc[x,y]) >= (xyzCat_counts.iloc[y, 2])):
            tally += 1
    xyzCat_new.iloc[x,14] = pos
    xyzCat_new.iloc[x,15] = tally

# %%
xyzCat_new['VarietyPerc'] = (xyzCat_new['VarietyCount']/xyzCat_new['NumCategories']*100).round(2)
xyzCat_new
# Out:
# primary_ca                      Arts & Culture  Body  Drinks  Entertainment  \
# Neighborho
# Astoria/LIC                               2.35  0.11   15.79           1.90
# Bed-Stuy                                  3.54  0.13   12.71           0.79
# Bed-Stuy/Bushwick                         5.08  0.00    9.60           1.13
# Bushwick                                  2.42  0.00   11.29           1.08
# Chelsea                                   8.45  0.04   16.42           6.40
# Elmhurst                                  0.00  0.00    8.23           1.73
# Flushing                                  1.31  0.00    6.99           3.06
# Greenpoint                                4.37  0.44   18.78           3.93
# Harlem                                    3.52  0.00    7.54           3.77
# Inwood                                    1.55  0.00    7.25           1.55
# Jackson Heights                           0.00  0.00   15.06           0.77
# LES                                      18.70  0.00   18.18           3.43
# LIC                                       0.00  0.00   17.78           0.00
# Ridgewood                                 2.83  0.00   11.31           2.12
# South Bronx                               1.93  0.00    3.87           0.55
# Williamsburg                              3.80  0.00   24.64           4.35
# Williamsburg/Bushwick/Bed-Stuy            7.73  0.00   11.82           1.82
#
# primary_ca                      Essentials  Fashion  Fitness   Food  Groups  \
# Neighborho
# Astoria/LIC                           4.26     0.00     0.11  69.09    1.79
# Bed-Stuy                             11.80     0.13     0.00  66.06    3.54
# Bed-Stuy/Bushwick                    13.56     0.56     0.56  64.97    2.82
# Bushwick                              5.65     0.00     0.00  75.81    2.15
# Chelsea                               1.37     0.12     0.00  56.46    3.18
# Elmhurst                              8.66     0.00     0.00  77.06    2.60
# Flushing                              1.31     0.00     0.00  83.84    0.44
# Greenpoint                            6.11     0.00     0.00  58.52    6.55
# Harlem                               17.84     0.00     0.00  63.82    2.26
# Inwood                               13.99     0.00     0.00  74.61    0.52
# Jackson Heights                       6.95     0.00     0.00  76.06    0.77
# LES                                   3.26     0.00     0.00  49.74    2.06
# LIC                                   2.22     0.00     0.00  80.00    0.00
# Ridgewood                             7.77     0.00     0.00  74.56    1.06
# South Bronx                          29.56     0.00     0.00  61.33    1.38
# Williamsburg                          4.35     0.36     0.18  56.34    3.44
# Williamsburg/Bushwick/Bed-Stuy       11.36     0.91     0.00  59.09    5.00
#
# primary_ca                      Home & Hobby  Lodging  Misc  Parks & Rec  \
# Neighborho
# Astoria/LIC                             0.22     4.26  0.00         0.00
# Bed-Stuy                                0.13     1.18  0.00         0.00
# Bed-Stuy/Bushwick                       0.00     1.69  0.00         0.00
# Bushwick                                0.27     0.81  0.54         0.00
# Chelsea                                 0.16     7.28  0.08         0.04
# Elmhurst                                0.00     1.73  0.00         0.00
# Flushing                                0.22     2.84  0.00         0.00
# Greenpoint                              0.44     0.87  0.00         0.00
# Harlem                                  0.00     1.01  0.25         0.00
# Inwood                                  0.00     0.00  0.52         0.00
# Jackson Heights                         0.39     0.00  0.00         0.00
# LES                                     0.51     3.95  0.17         0.00
# LIC                                     0.00     0.00  0.00         0.00
# Ridgewood                               0.00     0.00  0.00         0.35
# South Bronx                             0.28     0.83  0.00         0.00
# Williamsburg                            0.18     1.99  0.36         0.00
# Williamsburg/Bushwick/Bed-Stuy          0.00     2.27  0.00         0.00
#
# primary_ca                      Services  NumCategories  VarietyCount  \
# Neighborho
# Astoria/LIC                         0.11             11             7
# Bed-Stuy                            0.00             10             5
# Bed-Stuy/Bushwick                   0.00              9             5
# Bushwick                            0.00              9             3
# Chelsea                             0.00             12             7
# Elmhurst                            0.00              6             3
# Flushing                            0.00              8             2
# Greenpoint                          0.00              9             5
# Harlem                              0.00              8             4
# Inwood                              0.00              7             3
# Jackson Heights                     0.00              6             4
# LES                                 0.00              9             6
# LIC                                 0.00              3             2
# Ridgewood                           0.00              7             3
# South Bronx                         0.28              9             3
# Williamsburg                        0.00             11             6
# Williamsburg/Bushwick/Bed-Stuy      0.00              8             4
#
# primary_ca                      VarietyPerc
# Neighborho
# Astoria/LIC                           63.64
# Bed-Stuy                              50.00
# Bed-Stuy/Bushwick                     55.56
# Bushwick                              33.33
# Chelsea                               58.33
# Elmhurst                              50.00
# Flushing                              25.00
# Greenpoint                            55.56
# Harlem                                50.00
# Inwood                                42.86
# Jackson Heights                       66.67
# LES                                   66.67
# LIC                                   66.67
# Ridgewood                             42.86
# South Bronx                           33.33
# Williamsburg                          54.55
# Williamsburg/Bushwick/Bed-Stuy        50.00

# %%
xyzCat_new.to_csv('neighborhoodsVariety.csv')
